# %%
import warnings
from crimm import fetch_rcsb
from crimm.StructEntities.OrganizedModel import OrganizedModel
from crimm.Modeller.Solvator import Solvator

from crimm.Fetchers import fetch_rcsb
from crimm.Modeller import TopologyGenerator
from crimm.Modeller.CoordManipulator import CoordManipulator
from crimm.Modeller.LoopBuilder import ChainLoopBuilder
from crimm.Adaptors.PropKaAdaptors import PropKaProtonator
from crimm.Utils.StructureUtils import get_coords

import pycharmm
from pycharmm.settings import set_verbosity as pcm_set_verbosity
from pycharmm import write as pcm_write
from pycharmm import NonBondedScript

from crimm.Adaptors.pyCHARMMAdaptors import (
    load_chain, load_topology, load_water, load_ions, load_ligands,
    create_water_hs_from_charmm, fetch_coords_from_charmm, patch_disu_from_model,
    sd_minimize
)

import pycharmm.minimize as minimize
import pycharmm.energy as energy
from pycharmm import coor, crystal, image, cons_harm, cons_fix, generate

# %%
# cgenff excutable path is used later in topology generation
CGENFF_PATH = "/export/app/cgenff/silcsbio.2024.1/cgenff/cgenff"
PDBID = '4E0J' #'5iev'#'1bg8' #'3q4k' #'4pti' #'2HZI'

# %% [markdown]
# ## Fetch from RCSB
#
# The fetch_rcsb has be updated that it takes argument `organize`. When it is `True`, the structure will be organized into chain types, and an `OrganizedModel` will be returned instead of the unorganized structure entity.

# %%
structure = fetch_rcsb(
    '4pti',
    include_solvent=True, # We want to incude crystallographic water
    use_bio_assembly=True,
    organize=False,
    first_model_only=False
)

# %%
## the OrganinzedModel is improved with more feature and APIs
## and has become the main object that deals with modeling and interfacing pyCHARMM
## There will be another notebook showcasing more about OrganizedModel

model = OrganizedModel(structure)
model
# Out:
# NGLWidget()
# <OrganizedModel model=4PTI Polypeptide(L)=1 Solvent=1 >
# 	│
# 	├───<Polypeptide(L) id=A Residues=58>
# 	├──────Description: TRYPSIN INHIBITOR
# 	│
# 	├───<Solvent id=B Residues=60>
# 	├──────Residue ID(s): HOH
# 	├──────Description: water

# %%
## Place the model center to (0, 0, 0) and place the principle axis along x-axis
coord_man = CoordManipulator()
coord_man.load_entity(model)
coord_man.orient_coords()

# %%
# build missing loops if exist
for chain in model.protein:
    if not chain.is_continuous():
        # chain can be built in place now by specifying `inplace = True`
        looper = ChainLoopBuilder(chain, inplace = True)
        # looper.build_from_homology(max_num_match=10, identity_score_cutoff=0.95)
        # missing terminals will also be built if `include_terminal = True`
        looper.build_from_alphafold(include_terminal = False)

# %%
chain.is_continuous()
# Out:
# True

# %% [markdown]
# ## Generate Topology
#
# Topology generation is simplified by using organized model. If `cgenff_path` is specified, ligands are also generated

# %%
TopologyGenerator?
# Out:
# Init signature: TopologyGenerator(cgenff_excutable_path=None, cgenff_output_path=None)
# Docstring:
# Class for generating topology elements from the topology definition
# and parameters.
# The topology definition the parameters are loaded from the CHARMM 36 RTF and
# PRM files.
# If the cgenff_excutable_path is provided, the topology definition and
# parameters for the heterogen residues are generated by cgenff, and ligand mol2
# file and cgenff rtf file will be saved if cgenff_output_path is specified.
# Init docstring: Initialize the topology generator.
# File:           ~/crimm/crimm/Modeller/TopoLoader.py
# Type:           type
# Subclasses:

# %%
topo = TopologyGenerator(
    cgenff_excutable_path=CGENFF_PATH,
    cgenff_output_path='./cgenff/'
)
topo.generate_model(
    model,
    prot_first_patch='ACE',
    prot_last_patch='CT3',
    coerce=True
)
# Out:
# /home/truman/crimm/crimm/Modeller/TopoLoader.py:1188: UserWarning: Atom OXT from (58, 'ALA') is not defined in the topology file!
#   warnings.warn(
# /home/truman/crimm/crimm/Modeller/TopoLoader.py:743: UserWarning: No cmap found in <Polypeptide(L) id=A Residues=58>.
#   warnings.warn(
# /home/truman/crimm/crimm/Modeller/TopoLoader.py:470: UserWarning: Disulfide bond found between <Residue CYS het=  resseq=5 icode= > and <Residue CYS het=  resseq=55 icode= >! Removing hydrogen HG1 from the residues.
#   warnings.warn(
# /home/truman/crimm/crimm/Modeller/TopoLoader.py:470: UserWarning: Disulfide bond found between <Residue CYS het=  resseq=14 icode= > and <Residue CYS het=  resseq=38 icode= >! Removing hydrogen HG1 from the residues.
#   warnings.warn(
# /home/truman/crimm/crimm/Modeller/TopoLoader.py:470: UserWarning: Disulfide bond found between <Residue CYS het=  resseq=30 icode= > and <Residue CYS het=  resseq=51 icode= >! Removing hydrogen HG1 from the residues.
#   warnings.warn(

# %% [markdown]
# ### Printing out the TOPPAR and their Versions Being Used and Loaded

# %%
for rtf_type, topo_loader in topo.res_def_dict.items():
    print(rtf_type, 'toppar version:', topo_loader.rtf_version)
# Out:
# cgenff toppar version: 36.1
# protein toppar version: 36.2
# water_ions toppar version: 31.1

# %%
TopologyGenerator?
# Out:
# Init signature: TopologyGenerator(cgenff_excutable_path=None, cgenff_output_path=None)
# Docstring:
# Class for generating topology elements from the topology definition
# and parameters.
# The topology definition the parameters are loaded from the CHARMM 36 RTF and
# PRM files.
# If the cgenff_excutable_path is provided, the topology definition and
# parameters for the heterogen residues are generated by cgenff, and ligand mol2
# file and cgenff rtf file will be saved if cgenff_output_path is specified.
# Init docstring: Initialize the topology generator.
# File:           ~/crimm/crimm/Modeller/TopoLoader.py
# Type:           type
# Subclasses:

# %%
# Organized model
model
# Out:
# NGLWidget()
# <OrganizedModel model=4PTI Polypeptide(L)=1 Solvent=1 >
# 	│
# 	├───<Polypeptide(L) id=A Residues=58>
# 	├──────Description: TRYPSIN INHIBITOR
# 	│
# 	├───<Solvent id=B Residues=60>
# 	├──────Residue ID(s): HOH
# 	├──────Description: water

# %% [markdown]
# Modified residue creates breaks in chain after coersion

# %%
# Protonation 
protonator = PropKaProtonator(topo, pH = 6)
protonator.load_model(model)
# if there is any pathching applied in crimm, CHARMM PATCH command will be automatically run 
# when protein chains are loaded into CHARMM
protonator.apply_patches()
# Out:
# Unexpected number (14) of atoms in residue ARG   1 A   in conformation 1A
# Unexpected number (7) of atoms in residue ALA  58 A   in conformation 1A
# No protonation patches to apply on chain A.

# %%
## All the topology definition and parameter generated for the model is 
## organized in model.topology_loader. load_topology() takes care of 
## loading sequence and only loads what is need for the model
load_topology(model.topology_loader)
# Out:
#
#  CHARMM>     read rtf card -
#  CHARMM>     name /tmp/tmpk4emk5s0
#  VOPEN> Attempting to open::/tmp/tmpk4emk5s0::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> * PROTEIN RTF LOADED FROM CRIMM
#  TITLE> 36  2
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name /tmp/tmptb4707bx -
#  CHARMM>     flex
#  VOPEN> Attempting to open::/tmp/tmptb4707bx::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> * PROTEIN PRM LOADED FROM CRIMM
#  TITLE> *>>>> CHARMM36 ALL-HYDROGEN PARAMETER FILE FOR PROTEINS <<<<<<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> JAN. 2016 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read rtf card -
#  CHARMM>     name /tmp/tmpkp5fhxer -
#  CHARMM>     append
#  VOPEN> Attempting to open::/tmp/tmpkp5fhxer::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> * CGENFF RTF LOADED FROM CRIMM
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *          CGENFF: TOPOLOGY FOR THE CHARMM GENERAL FORCE FIELD V. 4.6          *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *
#
#  DRUDES PARTICLES WILL BE GENERATED AUTOMATICALLY FOR ALL ATOMS WITH NON-ZERO ALPHA
#  Thole-type dipole screening, Slater-Delta shape {S(u) = 1 - (1+u/2)*exp(-u)}, default radius =  1.300000
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name /tmp/tmpwp6p0y9r -
#  CHARMM>     append -
#  CHARMM>     flex
#  VOPEN> Attempting to open::/tmp/tmpwp6p0y9r::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> * CGENFF PRM LOADED FROM CRIMM
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *         CGENFF: PARAMETERS FOR THE CHARMM GENERAL FORCE FIELD V. 4.6         *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *  2017/8: IF PROTEIN, NUCLEIC ACID AND CARBOHYDRATE TOPOLOGY AND PARAMETER FILES
#  TITLE> *  ARE NOT READ PRIOR TO THE CGENFF FILES "WARNING: ATOMS IN NBFIX ' errors will
#  TITLE> *  BE ENCOUNTERED.  THESE CAN BE PASSED BY SETTING BOMLEV ( -2) PRIOR TO READING
#  TITLE> *  THIS FILE. IN ADDITION, WHEN GENERATING AROMATIC HALOGENS (CL, BR, I) WITH
#  TITLE> *  PRE C41B/C42A VERSIONS OF CHARMM "MISSING PARAMETER" ERRORS WILL BE
#  TITLE> *  ENCOUNTERED THAT ALSO REQUIRE SETTING BOMLEV ( -2).
#  TITLE> *
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL  CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L CLGR   -3.60000   3.18000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL  CLGR   -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL  BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L BRGR   -3.65000   3.33000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL  BRGR   -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1  CLGR   -0.40000   3.88000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2  CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3  CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4  CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1  CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1  BRGR   -0.30000   4.05000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2  BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3  BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4  BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1  BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C BRGR   -0.27000   3.52000 DONT EXIST
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     stream /tmp/tmpaostog6p
#  VOPEN> Attempting to open::/tmp/tmpaostog6p::
#  OPNLGU> Unit 99 opened for READONLY access to /tmp/tmpaostog6p
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * WATER ION TOPPAR LOADED FROM CRIMM
#  RDTITL> * TOPLOGY AND PARAMETER INFORMATION FOR WATER AND IONS.
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    !Testcase
#  CHARMM>    !test_water_ions.inp
#  CHARMM>
#
#  CHARMM>    ! IMPORTANT NOTE: this file contains NBFixes between carboxylates and sodium,
#  CHARMM>    ! which will only apply if the main files containing carboxylate atom types
#  CHARMM>    ! have been read in first!
#  CHARMM>
#
#  CHARMM>    !references
#  CHARMM>    !
#  CHARMM>    !TIP3P water model
#  CHARMM>    !
#  CHARMM>    !W.L. Jorgensen; J.Chandrasekhar; J.D. Madura; R.W. Impey;
#  CHARMM>    !M.L. Klein; "Comparison of simple potential functions for
#  CHARMM>    !simulating liquid water", J. Chem. Phys. 79 926-935 (1983).
#  CHARMM>    !
#  CHARMM>    !IONS
#  CHARMM>    !
#  CHARMM>    !Ions from Roux and coworkers
#  CHARMM>    !
#  CHARMM>    !Beglov, D. and Roux, B., Finite Representation of an Infinite
#  CHARMM>    !Bulk System: Solvent Boundary Potential for Computer Simulations,
#  CHARMM>    !Journal of Chemical Physics, 1994, 100: 9050-9063
#  CHARMM>    !
#  CHARMM>    !ZINC
#  CHARMM>    !
#  CHARMM>    !Stote, R.H. and Karplus, M. Zinc Binding in Proteins and
#  CHARMM>    !Solution: A Simple but Accurate Nonbonded Representation, PROTEINS:
#  CHARMM>    !Structure, Function, and Genetics 23:12-31 (1995)
#  CHARMM>
#
#  CHARMM>    !test "append" to determine if previous toppar files have been read and
#  CHARMM>    !add append to "read rtf card" if true
#  CHARMM>    set nat ?NATC
#  RDCMND substituted energy or value "?NATC" to "215"
#  Parameter: NAT <- "215"
#
#  CHARMM>    set app
#  Parameter: APP <- "" <empty>
#
#  CHARMM>    !We're exploiting what is arguably a bug in the parser. On the left hand side,
#  CHARMM>    !the quotes have priority, so NAT is correctly substituted. On the right hand
#  CHARMM>    !side, the ? has priority and NATC" (sic) is not a valid substitution...
#  CHARMM>    if "@NAT" ne "?NATC" if @nat ne 0 set app append
#  Parameter: NAT -> "215"
#  Parameter: NAT -> "215"
#  RDCMND: can not substitute energy "?NATC""
#  Comparing ""215"" and ""?NATC"".
#  IF test evaluated as true.  Performing command
#  Comparing "215" and "0".
#  IF test evaluated as true.  Performing command
#  Parameter: APP <- "APPEND"
#
#  CHARMM>
#
#  CHARMM>    read rtf card @app
#  Parameter: APP -> "APPEND"
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGY FOR WATER AND IONS
#  RDTITL> *
#
#  CHARMM>
#
#  CHARMM>    read para card flex @app
#  Parameter: APP -> "APPEND"
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS FOR WATER AND IONS
#  RDTITL> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>
#
#  CHARMM>    ! The following section contains NBFixes for sodium interacting with
#  CHARMM>    ! carboxylate oxygens of various CHARMM force fields. It will generate
#  CHARMM>    ! level -1 warnings whenever any of these force fields have not been
#  CHARMM>    ! read prior to the current stream file. Since we don't want to force
#  CHARMM>    ! the user to always read all the force fields, we're suppressing the
#  CHARMM>    ! warnings. The only side effect is that you will have "most severe
#  CHARMM>    ! warning was at level 0" at the end of your output. Also note that
#  CHARMM>    ! the user is responsible for reading the current file last if they
#  CHARMM>    ! want the NBFixes to apply. A more elegant solution would require new
#  CHARMM>    ! features to be added to CHARMM.
#  CHARMM>    ! parallel fix, to avoid duplicated messages in the log
#  CHARMM>    set para
#  Parameter: PARA <- "" <empty>
#
#  CHARMM>    if ?NUMNODE gt 1 set para node 0
#  RDCMND substituted energy or value "?NUMNODE" to "1"
#  Comparing "1" and "1".
#  IF test evaluated as false.  Skipping command
#
#  CHARMM>
#
#  CHARMM>    set wrn ?WRNLEV
#  RDCMND substituted energy or value "?WRNLEV" to "5"
#  Parameter: WRN <- "5"
#
#  CHARMM>    ! Some versions of CHARMM don't seem to initialize wrnlev...
#  CHARMM>    if "@WRN" eq "?WRNLEV" set wrn 5
#  Parameter: WRN -> "5"
#  RDCMND: can not substitute energy "?WRNLEV""
#  Comparing ""5"" and ""?WRNLEV"".
#  IF test evaluated as false.  Skipping command
#
#  CHARMM>    set bom ?bomlev
#  RDCMND substituted energy or value "?BOMLEV" to "0"
#  Parameter: BOM <- "0"
#
#  CHARMM>    WRNLEV -1 @PARA
#  Parameter: PARA -> "" <empty>
#
#  CHARMM>    BOMLEV -1 @PARA
#  Parameter: PARA -> "" <empty>
#
#  CHARMM>    read para card flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * NBFIX BETWEEN CARBOXYLATE AND SODIUM
#  RDTITL> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    BOMLEV @bom @PARA
#  Parameter: BOM -> "0"
#  Parameter: PARA -> "" <empty>
#
#  CHARMM>    WRNLEV @wrn @PARA
#  Parameter: WRN -> "5"
#  Parameter: PARA -> "" <empty>
#
#  CHARMM>
#
#  CHARMM>    return
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM    90

# %%
for chain in model.protein:
    load_chain(chain)
# we need to patch disulfide bonds in CHARMM
# the disu info is stored in model under model.connect_dict
patch_disu_from_model(model)
# Out:
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmpniu0rk4e
#  VOPEN> Attempting to open::/tmp/tmpniu0rk4e::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --    58 RESIDUES
#           ARG PRO ASP PHE CYS LEU GLU PRO PRO TYR THR GLY PRO CYS LYS ALA ARG ILE ILE ARG
#           TYR PHE TYR ASN ALA LYS ALA GLY LEU CYS GLN THR PHE VAL TYR GLY GLY CYS ARG ALA
#           LYS ARG ASN ASN PHE LYS SER ALA GLU ASP CYS MET ARG THR CYS GLY GLY ALA
#  ***** Message from SEQRDR ***** THE SYSTEM CONTAINS 12 TITRATABLE GROUPS
#  THE USER MUST PREDETERMINE THE PROTONATION STATE THROUGH THE SEQUENCE AND RTF
#  HIS -  0  HSD -  0  HSE -  0  HSP -  0  ASP -  2  GLU -  2  LYS -  4  TYR -  4
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  THE PATCH 'ACE' WILL BE USED FOR THE FIRST RESIDUE
#  THE PATCH 'CT3' WILL BE USED FOR THE LAST  RESIDUE
#  AUTGEN: Autogenerating specified angles and dihedrals.
#  GENPSF> Segment   1 has been generated. Its identifier is PROA.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =       58
#          Number of atoms         =      907   Number of groups     =      276
#          Number of bonds         =      918   Number of angles     =     1641
#          Number of dihedrals     =     2405   Number of impropers  =      156
#          Number of cross-terms   =       58   Number of autogens   =        0
#          Number of HB acceptors  =       79   Number of HB donors  =      119
#          Number of NB exclusions =        0   Total charge =    6.00000
#  QXFORM> Expanded format used.
#          More than 4 character atom type used.
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /tmp/tmpniu0rk4e -
#  CHARMM>     resi
#  VOPEN> Attempting to open::/tmp/tmpniu0rk4e::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  ** WARNING ** After reading, there are no coordinates for selected atom:    85     5 CYS  HG1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   214    14 CYS  HG1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   487    30 CYS  HG1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   600    38 CYS  HG1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   809    51 CYS  HG1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   875    55 CYS  HG1
#
#  ** A total of     6 selected atoms have no coordinates
#  *** LEVEL  2 WARNING *** BOMLEV IS    0
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
# [Excuting CHARMM Command] patch DISU PROA 5 PROA 55
#
#  CHARMM>     patch DISU PROA 5 PROA 55
#  ATOM  PROA     5        CYS      HG1      AND ALL REFERENCES TO IT DELETED.
#  ATOM  PROA     55       CYS      HG1      AND ALL REFERENCES TO IT DELETED.
#
#  Message from MAPIC: Atom numbers are changed.
#  DELTIC:         2 bonds deleted
#  DELTIC:         2 angles deleted
#  DELTIC:         6 dihedrals deleted
#  DELTIC:         2 donors deleted
#  AUTGEN: Autogenerating specified angles and dihedrals.
#  AUTOGEN:  1639 angles are removed before regeneration for selected atoms.
#  AUTOGEN:  2399 dihedrals are removed before regeneration for selected atoms.
#  PATCH: Check angles and dihedrals autogenerated.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =       58
#          Number of atoms         =      905   Number of groups     =      276
#          Number of bonds         =      917   Number of angles     =     1641
#          Number of dihedrals     =     2406   Number of impropers  =      156
#          Number of cross-terms   =       58   Number of autogens   =        0
#          Number of HB acceptors  =       79   Number of HB donors  =      117
#          Number of NB exclusions =        0   Total charge =    6.00000
#
# [Excuting CHARMM Command] patch DISU PROA 14 PROA 38
#
#  CHARMM>     patch DISU PROA 14 PROA 38
#  ATOM  PROA     14       CYS      HG1      AND ALL REFERENCES TO IT DELETED.
#  ATOM  PROA     38       CYS      HG1      AND ALL REFERENCES TO IT DELETED.
#
#  Message from MAPIC: Atom numbers are changed.
#  DELTIC:         2 bonds deleted
#  DELTIC:         2 angles deleted
#  DELTIC:         6 dihedrals deleted
#  DELTIC:         2 donors deleted
#  AUTGEN: Autogenerating specified angles and dihedrals.
#  AUTOGEN:  1639 angles are removed before regeneration for selected atoms.
#  AUTOGEN:  2400 dihedrals are removed before regeneration for selected atoms.
#  PATCH: Check angles and dihedrals autogenerated.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =       58
#          Number of atoms         =      903   Number of groups     =      276
#          Number of bonds         =      916   Number of angles     =     1641
#          Number of dihedrals     =     2407   Number of impropers  =      156
#          Number of cross-terms   =       58   Number of autogens   =        0
#          Number of HB acceptors  =       79   Number of HB donors  =      115
#          Number of NB exclusions =        0   Total charge =    6.00000
#
# [Excuting CHARMM Command] patch DISU PROA 30 PROA 51
#
#  CHARMM>     patch DISU PROA 30 PROA 51
#  ATOM  PROA     30       CYS      HG1      AND ALL REFERENCES TO IT DELETED.
#  ATOM  PROA     51       CYS      HG1      AND ALL REFERENCES TO IT DELETED.
#
#  Message from MAPIC: Atom numbers are changed.
#  DELTIC:         2 bonds deleted
#  DELTIC:         2 angles deleted
#  DELTIC:         6 dihedrals deleted
#  DELTIC:         2 donors deleted
#  AUTGEN: Autogenerating specified angles and dihedrals.
#  AUTOGEN:  1639 angles are removed before regeneration for selected atoms.
#  AUTOGEN:  2401 dihedrals are removed before regeneration for selected atoms.
#  PATCH: Check angles and dihedrals autogenerated.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =       58
#          Number of atoms         =      901   Number of groups     =      276
#          Number of bonds         =      915   Number of angles     =     1641
#          Number of dihedrals     =     2408   Number of impropers  =      156
#          Number of cross-terms   =       58   Number of autogens   =        0
#          Number of HB acceptors  =       79   Number of HB donors  =      113
#          Number of NB exclusions =        0   Total charge =    6.00000

# %%
# model.ligand+model.phos_ligand+model.co_solvent is the concatenated list of entities
load_ligands(model.ligand+model.phos_ligand+model.co_solvent)
# load_ligands(model.ligand)
# Out:
# []

# %% [markdown]
# ## Minimize the Protein Chain First

# %%
# Specify nonbonded python object called my_nbonds - this just sets it up
# equivalant CHARMM scripting command: 
# nbonds cutnb 18 ctonnb 13 ctofnb 17 cdie eps 1 atom vatom fswitch vfswitch
non_bonded_script = NonBondedScript(
    cutnb=18.0, ctonnb=13.0, ctofnb=17.0,
    eps=1.0,
    cdie=True,
    atom=True, vatom=True,
    fswitch=True, vfswitch=True
)
# select the C-alpha atoms for harmonic restraints
cons_harm_atoms = pycharmm.SelectAtoms(atom_type='CA')
ener_dict = sd_minimize(300, non_bonded_script, cons_harm_selection=cons_harm_atoms)
# Out:
#
#  CHARMM>     nbonds cutnb 18.0 -
#  CHARMM>     ctonnb 13.0 -
#  CHARMM>     ctofnb 17.0 -
#  CHARMM>     eps 1.0 -
#  CHARMM>     cdie -
#  CHARMM>     atom -
#  CHARMM>     vatom -
#  CHARMM>     fswitch -
#  CHARMM>     vfswitch
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 18.000 CTEXNB =999.000 CTONNB = 13.000 CTOFNB = 17.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  <MAKINB> with mode   5 found   2556 exclusions and   2364 interactions(1-4)
#  <MAKGRP> found    826 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   405451 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    285445 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      5796 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#
#  CHARMM>
#
#  CSTRAN: Harmonic Restraints
#           ABSOlute type as set number  1.  Number of selected atoms:     58
#           Reference coordinates set to main coordinates.
#           Mass weighting will NOT be used for new restraints.
#           The force constant of      20.00000 will be used.
#           An exponent of  2 will be used.
#           The XYZ scale factors are:       1.00000       1.00000       1.00000
#           A total of     58 atoms are restrained.
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 18.000 CTEXNB =999.000 CTONNB = 13.000 CTOFNB = 17.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are   285445 atom  pairs and     4920 atom  exclusions.
#  There are        0 group pairs and      826 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   405451 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    285445 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      5796 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  PRNHBD: CUToff Hydrogen Bond  distance =    0.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
#
#
#
#  STEEPD> An energy minimization has been requested.
#
#  NSTEP  =          300   NPRINT =           10
#  STEP   =    0.0200000   TOLFUN =    0.0010000
#  TOLGRD =    0.0010000   TOLSTP =    0.0000000
#
# MINI MIN: Cycle      ENERgy      Delta-E         GRMS    Step-size
# MINI INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# MINI CROSS:           CMAPs        PMF1D        PMF2D        PRIMO
# MINI EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>        0    286.71901      0.00000     51.08184      0.02000
# MINI INTERN>      145.81795    428.21681     18.92665    527.81437    247.31164
# MINI CROSS>         1.04323      0.00000      0.00000      0.00000
# MINI EXTERN>      189.55842  -1271.97005      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       10   -696.69441    983.41342      3.07109      0.00373
# MINI INTERN>       54.89201    134.32003      9.28328    511.53334     17.51395
# MINI CROSS>        -7.10939      0.00000      0.00000      0.00000
# MINI EXTERN>     -142.07203  -1276.20875      0.00000      0.00000      0.00000
# MINI CONSTR>        1.15317      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       20   -760.79052     64.09611      2.03493      0.00167
# MINI INTERN>       48.48951    126.92829      9.02862    502.58551      7.75439
# MINI CROSS>        -9.70819      0.00000      0.00000      0.00000
# MINI EXTERN>     -165.13434  -1282.68277      0.00000      0.00000      0.00000
# MINI CONSTR>        1.94845      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       30   -782.10660     21.31608      3.05291      0.00180
# MINI INTERN>       52.44457    124.05086      8.88903    497.08925      6.10066
# MINI CROSS>       -10.76711      0.00000      0.00000      0.00000
# MINI EXTERN>     -173.97926  -1288.38510      0.00000      0.00000      0.00000
# MINI CONSTR>        2.45050      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       40   -795.75026     13.64366      3.36271      0.00193
# MINI INTERN>       54.36345    124.34654      8.81959    493.37927      5.85062
# MINI CROSS>       -11.56476      0.00000      0.00000      0.00000
# MINI EXTERN>     -180.26649  -1293.54829      0.00000      0.00000      0.00000
# MINI CONSTR>        2.86982      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# /home/truman/crimm/crimm/Adaptors/pyCHARMMAdaptors.py:454: UserWarning: Absolute harmonic restraints setup success: True
#   warnings.warn(f"Absolute harmonic restraints setup success: {has_cons_harm}")
#  UPDECI: Nonbond update at step        50
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   405451 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    285154 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      5772 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>       50   -811.07500     15.32474      0.90090      0.00087
# MINI INTERN>       52.54054    124.86653      8.74555    490.74071      5.89626
# MINI CROSS>       -12.17889      0.00000      0.00000      0.00000
# MINI EXTERN>     -185.23420  -1299.69285      0.00000      0.00000      0.00000
# MINI CONSTR>        3.24135      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       60   -819.97845      8.90344      1.03742      0.00093
# MINI INTERN>       53.56299    125.89118      8.72032    488.82762      6.00758
# MINI CROSS>       -12.68961      0.00000      0.00000      0.00000
# MINI EXTERN>     -189.28994  -1304.58099      0.00000      0.00000      0.00000
# MINI CONSTR>        3.57240      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       70   -826.15927      6.18082      1.80716      0.00100
# MINI INTERN>       55.34709    126.88716      8.71952    487.44844      6.07595
# MINI CROSS>       -13.06000      0.00000      0.00000      0.00000
# MINI EXTERN>     -192.38977  -1309.02620      0.00000      0.00000      0.00000
# MINI CONSTR>        3.83855      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       80   -833.05680      6.89753      0.53896      0.00045
# MINI INTERN>       54.05503    127.58894      8.68378    486.52764      6.15724
# MINI CROSS>       -13.39656      0.00000      0.00000      0.00000
# MINI EXTERN>     -194.61940  -1312.10227      0.00000      0.00000      0.00000
# MINI CONSTR>        4.04880      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       90   -837.04672      3.98992      1.95647      0.00116
# MINI INTERN>       56.76421    128.23204      8.72173    485.53888      6.16301
# MINI CROSS>       -13.59134      0.00000      0.00000      0.00000
# MINI EXTERN>     -196.84000  -1316.28013      0.00000      0.00000      0.00000
# MINI CONSTR>        4.24488      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Nonbond update at step       100
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   405451 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    285008 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      5757 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      100   -843.14748      6.10076      0.47738      0.00052
# MINI INTERN>       54.94963    128.94081      8.67572    484.92360      6.22652
# MINI CROSS>       -13.86381      0.00000      0.00000      0.00000
# MINI EXTERN>     -198.37478  -1319.03319      0.00000      0.00000      0.00000
# MINI CONSTR>        4.40801      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      110   -847.74986      4.60237      0.45986      0.00056
# MINI INTERN>       55.33655    129.54914      8.67412    484.25254      6.25392
# MINI CROSS>       -14.05142      0.00000      0.00000      0.00000
# MINI EXTERN>     -199.90908  -1322.41949      0.00000      0.00000      0.00000
# MINI CONSTR>        4.56385      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      120   -851.97420      4.22434      0.57069      0.00060
# MINI INTERN>       55.62245    130.20095      8.66992    483.67102      6.28271
# MINI CROSS>       -14.22898      0.00000      0.00000      0.00000
# MINI EXTERN>     -201.21117  -1325.68569      0.00000      0.00000      0.00000
# MINI CONSTR>        4.70459      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      130   -855.59682      3.62263      1.05859      0.00064
# MINI INTERN>       55.96039    131.01220      8.66411    483.17621      6.31526
# MINI CROSS>       -14.42197      0.00000      0.00000      0.00000
# MINI EXTERN>     -202.30541  -1328.83051      0.00000      0.00000      0.00000
# MINI CONSTR>        4.83289      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      140   -859.13594      3.53912      1.14518      0.00069
# MINI INTERN>       56.26653    131.53143      8.66753    482.71352      6.34064
# MINI CROSS>       -14.54023      0.00000      0.00000      0.00000
# MINI EXTERN>     -203.22084  -1331.83889      0.00000      0.00000      0.00000
# MINI CONSTR>        4.94436      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Nonbond update at step       150
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   405451 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    284941 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      5766 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      150   -862.26761      3.13167      1.18729      0.00074
# MINI INTERN>       56.52190    131.94509      8.67004    482.30970      6.36285
# MINI CROSS>       -14.62339      0.00000      0.00000      0.00000
# MINI EXTERN>     -203.94104  -1334.55207      0.00000      0.00000      0.00000
# MINI CONSTR>        5.03931      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      160   -865.47091      3.20330      1.25698      0.00080
# MINI INTERN>       56.78677    132.38861      8.67815    481.89849      6.38780
# MINI CROSS>       -14.70939      0.00000      0.00000      0.00000
# MINI EXTERN>     -204.59886  -1337.43834      0.00000      0.00000      0.00000
# MINI CONSTR>        5.13586      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      170   -868.19245      2.72154      1.38107      0.00086
# MINI INTERN>       57.04684    132.79815      8.68191    481.53558      6.41013
# MINI CROSS>       -14.77875      0.00000      0.00000      0.00000
# MINI EXTERN>     -205.10119  -1340.00425      0.00000      0.00000      0.00000
# MINI CONSTR>        5.21912      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      180   -871.01412      2.82167      1.50858      0.00092
# MINI INTERN>       57.33793    133.24398      8.69044    481.14826      6.43441
# MINI CROSS>       -14.84812      0.00000      0.00000      0.00000
# MINI EXTERN>     -205.55706  -1342.76912      0.00000      0.00000      0.00000
# MINI CONSTR>        5.30515      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      190   -874.46056      3.44644      0.35274      0.00041
# MINI INTERN>       57.37553    132.55011      8.68830    480.68934      6.42729
# MINI CROSS>       -14.66215      0.00000      0.00000      0.00000
# MINI EXTERN>     -205.90127  -1344.99566      0.00000      0.00000      0.00000
# MINI CONSTR>        5.36794      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Nonbond update at step       200
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   405451 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    284864 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      5762 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      200   -877.20629      2.74573      0.35676      0.00044
# MINI INTERN>       57.55648    132.81096      8.69137    480.28639      6.44595
# MINI CROSS>       -14.68674      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.19959  -1347.55717      0.00000      0.00000      0.00000
# MINI CONSTR>        5.44606      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      210   -879.74026      2.53397      0.44038      0.00048
# MINI INTERN>       57.80240    132.97619      8.69329    479.87965      6.46117
# MINI CROSS>       -14.68689      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.42434  -1349.96085      0.00000      0.00000      0.00000
# MINI CONSTR>        5.51913      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      220   -882.00559      2.26533      0.83679      0.00051
# MINI INTERN>       58.33943    132.97704      8.69109    479.44122      6.46975
# MINI CROSS>       -14.63939      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.59806  -1352.27702      0.00000      0.00000      0.00000
# MINI CONSTR>        5.59036      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      230   -884.22634      2.22076      0.90863      0.00055
# MINI INTERN>       58.53244    133.14944      8.69204    479.05309      6.48336
# MINI CROSS>       -14.64673      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.70983  -1354.43869      0.00000      0.00000      0.00000
# MINI CONSTR>        5.65853      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      240   -886.17701      1.95066      0.94067      0.00059
# MINI INTERN>       58.66547    133.31782      8.69587    478.70972      6.49587
# MINI CROSS>       -14.65653      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.77311  -1356.35170      0.00000      0.00000      0.00000
# MINI CONSTR>        5.71958      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Nonbond update at step       250
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   405451 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    284819 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      5768 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      250   -888.46029      2.28328      0.29817      0.00027
# MINI INTERN>       58.03966    134.01807      8.71840    478.44642      6.52735
# MINI CROSS>       -14.81309      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.78336  -1358.39813      0.00000      0.00000      0.00000
# MINI CONSTR>        5.78440      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      260   -889.77350      1.31320      1.09910      0.00069
# MINI INTERN>       59.00223    133.59028      8.69753    478.05206      6.51669
# MINI CROSS>       -14.66620      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.82465  -1359.98236      0.00000      0.00000      0.00000
# MINI CONSTR>        5.84092      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      270   -891.91228      2.13878      0.38247      0.00031
# MINI INTERN>       58.15072    134.47142      8.73483    477.85954      6.55350
# MINI CROSS>       -14.85983      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.78214  -1361.94172      0.00000      0.00000      0.00000
# MINI CONSTR>        5.90140      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      280   -893.37393      1.46165      0.26370      0.00033
# MINI INTERN>       58.24009    134.50883      8.73334    477.61201      6.55834
# MINI CROSS>       -14.84466      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.77697  -1363.35540      0.00000      0.00000      0.00000
# MINI CONSTR>        5.95047      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      290   -894.85805      1.48412      0.33562      0.00035
# MINI INTERN>       58.26877    134.76165      8.74451    477.37994      6.57014
# MINI CROSS>       -14.87072      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.75537  -1364.96127      0.00000      0.00000      0.00000
# MINI CONSTR>        6.00429      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Nonbond update at step       300
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   405451 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    284796 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      5773 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      300   -896.23398      1.37592      0.39883      0.00038
# MINI INTERN>       58.31764    134.97174      8.75453    477.17038      6.57932
# MINI CROSS>       -14.88658      0.00000      0.00000      0.00000
# MINI EXTERN>     -206.73694  -1366.45884      0.00000      0.00000      0.00000
# MINI CONSTR>        6.05477      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  STEEPD> Minimization exiting with number of steps limit (       300) exceeded.
#
# STPD MIN: Cycle      ENERgy      Delta-E         GRMS    Step-size
# STPD INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# STPD CROSS:           CMAPs        PMF1D        PMF2D        PRIMO
# STPD EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# STPD CONSTR:       HARMonic    CDIHedral          CIC     RESDistance       NOE
#  ----------       ---------    ---------    ---------    ---------    ---------
# STPD>      300   -896.23398      1.37592      0.39883      0.00046
# STPD INTERN>       58.31764    134.97174      8.75453    477.17038      6.57932
# STPD CROSS>       -14.88658      0.00000      0.00000      0.00000
# STPD EXTERN>     -206.73694  -1366.45884      0.00000      0.00000      0.00000
# STPD CONSTR>        6.05477      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 18.000 CTEXNB =999.000 CTONNB = 13.000 CTOFNB = 17.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are   284796 atom  pairs and     4920 atom  exclusions.
#  There are        0 group pairs and      826 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   405451 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    284796 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      5773 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  PRNHBD: CUToff Hydrogen Bond  distance =    0.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
#
# ENER ENR:  Eval#     ENERgy      Delta-E         GRMS
# ENER INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# ENER CROSS:           CMAPs        PMF1D        PMF2D        PRIMO
# ENER EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
#  ----------       ---------    ---------    ---------    ---------    ---------
# ENER>        0   -902.28875      6.05477      0.58367
# ENER INTERN>       58.31764    134.97174      8.75453    477.17038      6.57932
# ENER CROSS>       -14.88658      0.00000      0.00000      0.00000
# ENER EXTERN>     -206.73694  -1366.45884      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------

# %% [markdown]
# ## Sync Coord with pyCHARMM
# We need to update the coords of crimm protein after minimization

# %%
## This is the new API for crimm sync coordinates with CHARMM
## The old sync_coord only works in a limited number of situations thus is DEPRECATED
fetch_coords_from_charmm(model.protein+model.ligand+model.phos_ligand+model.co_solvent)

# %%
model
# Out:
# NGLWidget()
# <OrganizedModel model=4PTI Polypeptide(L)=1 Solvent=1 >
# 	│
# 	├───<Polypeptide(L) id=A Residues=58>
# 	├──────Description: TRYPSIN INHIBITOR
# 	│
# 	├───<Solvent id=B Residues=60>
# 	├──────Residue ID(s): HOH
# 	├──────Description: water

# %% [markdown]
# ## Solvation

# %%
solvator = Solvator(model)
# we want to keep the crystallograpic water using remove_existing_water=False
# doc string available for Solvator and
added_water = solvator.solvate(
    cutoff=8.0, solvcut=2.1, remove_existing_water=False, orient_coords=False
)
# Solvator.add_balancing_ions will add either sodium (SOD) or chloride (CLA)
# to the solvent according to the total charge of the system
balancing_ion_chain = solvator.add_balancing_ions()
# Out:
# Total charges before adding ions: 6.0
#   [Chain A] 6.0

# %% [markdown]
# ## Doc Strings for Solvator

# %%
Solvator?
# Out:
# Init signature: Solvator(entity) -> None
# Docstring:
# Solvates a Structure, Model, or Chain level entity with water molecules.
# The solvated entity will be returned as a Model level entity. The solvated
# entity will be centered in a cubic box with side length equal to the
# maximum dimension of the entity plus the cutoff distance. (i.e., Coordinates
# will be oriented using CoordManipulator.orient_coords() before solvation.)
# The solvcut distance is the distance from the solute at which water
# molecules will be removed. The solvcut distance is used to remove water
# molecules that are too close to the solute.
# If altloc atoms exist in the entity, the first altloc atoms will be used to
# determine water molecules location during solvation.
#
# Parameters
# ----------
# entity : Structure, Model, or Chain level entity
#     The entity to solvate. If a Structure level entity is provided, the
#     first Model will be solvated. If a Model level entity is provided, all
#     chains in the model will be solvated. If a Chain level entity is
#     provided, the chain will be solvated. The entity is modified in place.
#
# Examples
# --------
# >>> from crimm import fetch_rcsb
# >>> from crimm.Modeller.Solvator import Solvator
#
# >>> fisrt_model = fetch_rcsb('5igv')
# >>> solvator = Solvator()
# >>> solvated_model = solvator.solvate(
#         fisrt_model, cutoff=8.0, solvcut=2.1, remove_existing_water=True
#     )
# >>> water_chains = [
#     chain for chain in solvated if chain.chain_type == 'Solvent'
# ]
#
# Note that water chains are named W[A-Z] and have a maximum number of 9999 residues
# >>> water_chains
# [<Solvent id=WA Residues=9999>, <Solvent id=WB Residues=2486>]
# >>> solvator.water_box_coords.shape # shape in (N waters, 3 atoms, 3 coords)
# (12485, 3, 3)
# >>> chain = structure[1]['A'] # get chain A from the first model
# >>> solvated_chain = solvator.solvate(chain)
#
# More water molecules are added to solvate the chain since the ligands are
# not included in the solvation process
# >>> solvator.water_box_coords.shape
# (12531, 3, 3)
# File:           ~/crimm/crimm/Modeller/Solvator.py
# Type:           type
# Subclasses:

# %%
Solvator.solvate?
# Out:
# Signature:
# Solvator.solvate(
#     self,
#     cutoff=9.0,
#     solvcut=2.1,
#     remove_existing_water=True,
#     orient_coords=True,
#     box_type='cube',
# ) -> crimm.StructEntities.Model.Model
# Docstring:
# Solvates the entity and returns a Model level entity. The solvated
# entity will be centered in a cubic box with side length equal to the
# maximum dimension of the entity plus the cutoff distance. (i.e.,
# Coordinates will be oriented using CoordManipulator.orient_coords()
# before solvation.) The solvcut distance is the distance from the solute
# at which water molecules will be removed. The solvcut distance is used
# to remove water molecules that are too close to the solute. If altloc
# atoms exist in the entity, the first altloc atoms will be used to
# determine water molecules location during solvation.
#
# Parameters
# ----------
# cutoff : float, optional
#     The distance from the solute to the edge of the cubic box. The
#     default is 9.0.
# solvcut : float, optional
#     The distance from the solute at which water molecules will be
#     removed. The default is 2.10.
# remove_existing_water : bool, optional
#     If True, remove existing water molecules from the entity. The default
#     is True.
# File:      ~/crimm/crimm/Modeller/Solvator.py
# Type:      function

# %%
Solvator.add_balancing_ions?
# Out:
# Signature:
# Solvator.add_balancing_ions(
#     self,
#     present_charge=None,
#     cation='SOD',
#     anion='CLA',
#     skip_undefined=True,
# ) -> crimm.StructEntities.Chain.Ion
# Docstring:
# Add balancing ions to the solvated entity to bring total charge to zero.
# The default cation is Na+ and the default anion is Cl-. If the entity is
# not a solvated entity, a ValueError will be raised. A random selection of
# water molecules in the water box will be replaced with balancing ions.
# Returns a chain containing the balancing ions.
#
# Parameters
# ----------
# entity : Structure, Model, or Chain level entity
#     The solvated entity to add balancing ions to.
# present_charge : int, optional
#     The present charge of the solvated entity. If None, the charge will be
#     calculated from the entity. The default is None. If for any reason you
#     want to balance the charge to a non-zero value, you can specify it here.
# cation : str, optional
#     The cation to use. The default is 'SOD' (Na+).
# anion : str, optional
#     The anion to use. The default is 'CLA' (Cl-).
#
# Returns
# -------
# ion_chain : Chain
#     A chain containing the balancing ions.
# File:      ~/crimm/crimm/Modeller/Solvator.py
# Type:      function

# %% [markdown]
# ## Model after Solvation
#
# Note that we have added 4 chloride ions as chain IA since the total charge was **+4**.<br>
# The water box has to be splitted into two chains due to PDB residue number limit to **9999**.

# %%
model
# Out:
# NGLWidget()
# <OrganizedModel model=4PTI Polypeptide(L)=1 Solvent=2 Ion=1 >
# 	│
# 	├───<Polypeptide(L) id=A Residues=58>
# 	├──────Description: TRYPSIN INHIBITOR
# 	│
# 	├───<Solvent id=B Residues=60>
# 	├──────Residue ID(s): HOH
# 	├──────Description: water
# 	│
# 	├───<Solvent id=WA Residues=3691>
# 	├──────Description: water
# 	│
# 	├───<Ion id=IA Residues=6>
# 	├──────Description: balancing ions (CLA)

# %% [markdown]
# ## Load other Entities into CHARMM
# Currently Ligand, Nucleophosphate, and CoSolvent can be automatically generated by TopologyLoader. <br>
# Thus, if they exist, they can be safely loaded into CHARMM

# %%
model.solvent
# Out:
# [<Solvent id=B Residues=60>, <Solvent id=WA Residues=3691>]

# %%
load_ions(model.ion)
# This loads both crystallographic water and the water box generated by Solvator
load_water(model.solvent)
# Since crimm cannot build hydrogens on the crystallographic water yet
# we will build them in CHARMM and copy their coords to crimm
create_water_hs_from_charmm(model)
# Out:
# [crimm] Loading ion chain IO00
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmp0gs0_p1n
#  VOPEN> Attempting to open::/tmp/tmp0gs0_p1n::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --     6 RESIDUES
#           CLA     CLA     CLA     CLA     CLA     CLA
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  GENPSF> Segment   2 has been generated. Its identifier is IO00.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        2   Number of residues   =       64
#          Number of atoms         =      907   Number of groups     =      282
#          Number of bonds         =      915   Number of angles     =     1641
#          Number of dihedrals     =     2408   Number of impropers  =      156
#          Number of cross-terms   =       58   Number of autogens   =        0
#          Number of HB acceptors  =       79   Number of HB donors  =      113
#          Number of NB exclusions =        0   Total charge =   -0.00000
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /tmp/tmp0gs0_p1n -
#  CHARMM>     resid
#  VOPEN> Attempting to open::/tmp/tmp0gs0_p1n::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
# [crimm] Loading water chain WT00
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmpl37__kgi
#  VOPEN> Attempting to open::/tmp/tmpl37__kgi::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --    60 RESIDUES
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  GENPSF> Segment   3 has been generated. Its identifier is WT00.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        3   Number of residues   =      124
#          Number of atoms         =     1087   Number of groups     =      342
#          Number of bonds         =     1095   Number of angles     =     1701
#          Number of dihedrals     =     2408   Number of impropers  =      156
#          Number of cross-terms   =       58   Number of autogens   =        0
#          Number of HB acceptors  =      139   Number of HB donors  =      233
#          Number of NB exclusions =        0   Total charge =   -0.00000
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /tmp/tmpl37__kgi -
#  CHARMM>     resid
#  VOPEN> Attempting to open::/tmp/tmpl37__kgi::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  ** WARNING ** After reading, there are no coordinates for selected atom:   909    65 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   910    65 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:   912    66 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   913    66 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:   915    67 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   916    67 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:   918    68 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   919    68 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:   921    69 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   922    69 TIP3 H2
#
#  ** A total of   120 selected atoms have no coordinates
#  *** LEVEL  2 WARNING *** BOMLEV IS    0
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
# [crimm] Loading water chain WT01
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmpjdt3153q
#  VOPEN> Attempting to open::/tmp/tmpjdt3153q::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --  3691 RESIDUES
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  GENPSF> Segment   4 has been generated. Its identifier is WT01.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        4   Number of residues   =     3815
#          Number of atoms         =    12160   Number of groups     =     4033
#          Number of bonds         =    12168   Number of angles     =     5392
#          Number of dihedrals     =     2408   Number of impropers  =      156
#          Number of cross-terms   =       58   Number of autogens   =        0
#          Number of HB acceptors  =     3830   Number of HB donors  =     7615
#          Number of NB exclusions =        0   Total charge =   -0.00000
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /tmp/tmpjdt3153q -
#  CHARMM>     resid
#  VOPEN> Attempting to open::/tmp/tmpjdt3153q::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  ** WARNING ** After reading, there are no coordinates for selected atom:   909    65 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   910    65 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:   912    66 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   913    66 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:   915    67 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   916    67 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:   918    68 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   919    68 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:   921    69 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:   922    69 TIP3 H2
#
#  ** A total of   120 selected atoms have no coordinates
#  *** LEVEL  2 WARNING *** BOMLEV IS    0
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     hbuild sele SEGI WT00 .and. .not. TYPE O* end
#  SELRPN>    120 atoms have been selected out of  12160
#  PRNHBD: CUToff Hydrogen Bond  distance =    0.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
#
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 18.000 CTEXNB =999.000 CTONNB = 13.000 CTOFNB = 17.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  <MAKINB> with mode   5 found  13809 exclusions and   2364 interactions(1-4)
#  <MAKGRP> found    826 group exclusions.
#
#  CUToff Hydrogen Bond  distance =    0.5000           Angle =   90.0000
#  CuT switching ON HB dist. =     3.5000 OFf HB dist. =    4.0000
#  CuT switching ON Hb Angle =    50.0000 OFf Hb Angle =   70.0000
#  ACCEptor antecedents included
#  dihedral PHI STePs for spin =   10.0000
#  cutoff for water acceptor search CUTWat=    7.5000
#
#
#  NBONDX:      4494 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     53       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.60507 A.
#
#  NBONDX:      3648 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     2        TIP3     OH2     .
#  Minimum distance between this water and protein is  1.73085 A.
#
#  NBONDX:      4314 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     28       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.73450 A.
#
#  NBONDX:      4396 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     49       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.74536 A.
#
#  NBONDX:      4450 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     27       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.76818 A.
#
#  NBONDX:      3856 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     36       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.84322 A.
#
#  NBONDX:      4370 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     13       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.85221 A.
#
#  NBONDX:      4028 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     48       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.86712 A.
#
#  NBONDX:      4470 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     42       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.86784 A.
#
#  NBONDX:      4498 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     10       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.90522 A.
#
#  NBONDX:      4266 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     50       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.95267 A.
#
#  NBONDX:      4478 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     33       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.95429 A.
#
#  NBONDX:      4174 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     26       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.96908 A.
#
#  NBONDX:      4172 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     18       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.97629 A.
#
#  NBONDX:      4412 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     15       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.98131 A.
#
#  NBONDX:      4604 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     38       TIP3     OH2     .
#  Minimum distance between this water and protein is  1.98447 A.
#
#  NBONDX:      4180 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     25       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.00775 A.
#
#  NBONDX:      4524 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     58       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.04703 A.
#
#  NBONDX:      4516 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     17       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.06635 A.
#
#  NBONDX:      4562 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     43       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.07344 A.
#
#  NBONDX:      4528 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     29       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.08567 A.
#
#  NBONDX:      4420 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     12       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.09525 A.
#
#  NBONDX:      3708 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     4        TIP3     OH2     .
#  Minimum distance between this water and protein is  2.10266 A.
#
#  NBONDX:      4450 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     44       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.10412 A.
#
#  NBONDX:      4388 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     22       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.10856 A.
#
#  NBONDX:      4414 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     1        TIP3     OH2     .
#  Minimum distance between this water and protein is  2.12281 A.
#
#  NBONDX:      3610 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     45       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.12615 A.
#
#  NBONDX:      4266 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     56       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.13025 A.
#
#  NBONDX:      4596 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     41       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.13210 A.
#
#  NBONDX:      4372 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     34       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.15915 A.
#
#  NBONDX:      4426 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     23       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.20890 A.
#
#  NBONDX:      4458 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     14       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.24880 A.
#
#  NBONDX:      4466 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     6        TIP3     OH2     .
#  Minimum distance between this water and protein is  2.28708 A.
#
#  NBONDX:      4572 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     57       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.29246 A.
#
#  NBONDX:      4568 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     52       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.29878 A.
#
#  NBONDX:      4038 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     35       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.31596 A.
#
#  NBONDX:      4178 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     20       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.31646 A.
#
#  NBONDX:      4390 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     54       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.38194 A.
#
#  NBONDX:      4548 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     55       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.40285 A.
#
#  NBONDX:      4512 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     60       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.44276 A.
#
#  NBONDX:      4138 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     3        TIP3     OH2     .
#  Minimum distance between this water and protein is  2.44901 A.
#
#  NBONDX:      4516 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     16       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.48132 A.
#
#  NBONDX:      4512 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     19       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.48487 A.
#
#  NBONDX:      4210 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     32       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.48592 A.
#
#  NBONDX:      4474 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     11       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.52567 A.
#
#  NBONDX:      4398 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     47       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.56091 A.
#
#  NBONDX:      4318 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     5        TIP3     OH2     .
#  Minimum distance between this water and protein is  2.60500 A.
#
#  NBONDX:      4582 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     9        TIP3     OH2     .
#  Minimum distance between this water and protein is  2.61845 A.
#
#  NBONDX:      4396 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     59       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.64320 A.
#
#  NBONDX:      4472 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     31       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.64620 A.
#
#  NBONDX:      3292 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     24       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.67938 A.
#
#  NBONDX:      4624 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     40       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.69505 A.
#
#  NBONDX:      4606 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     7        TIP3     OH2     .
#  Minimum distance between this water and protein is  2.69809 A.
#
#  NBONDX:      4576 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     30       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.74623 A.
#
#  NBONDX:      4690 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     39       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.75447 A.
#
#  NBONDX:      4344 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     51       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.76702 A.
#
#  NBONDX:      4498 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     46       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.77132 A.
#
#  NBONDX:      4256 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     21       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.86471 A.
#
#  NBONDX:      4348 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     37       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.87988 A.
#
#  NBONDX:      4564 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     8        TIP3     OH2     .
#  Minimum distance between this water and protein is  2.95806 A.

# %%
# We can visualize the crystallographic water and see the hydrogens are added
model.solvent[0]
# Out:
# NGLWidget()
# <Solvent id=B Residues=60>
#   Residue ID(s): HOH
#   Description: water

# %% [markdown]
# ## Set up PBC and Minimize Water

# %%
# organize segids and ion types for image and cons_fix
non_solvent_segids = set()
all_ion_types = set()
for chain in model:
    if chain.chain_type == 'Solvent':
        continue
    elif chain.chain_type == 'Ion':
        for res in chain:
            all_ion_types.add(res.resname)
    else:
        for res in chain:
            non_solvent_segids.add(res.segid)

# %%
# anything but solvent or ions in the model
non_solvent_segids
# Out:
# {'PROA'}

# %%
# all types of ions loaded in pyCHARMM by crimm
all_ion_types
# Out:
# {'CLA'}

# %%
# CHARMM scripting: crystal define cubic @boxsize @boxsize @boxsize 90 90 90
crystal.define_cubic(solvator.box_dim)
# CHARMM scripting: crystal build cutoff @boxhalf noper 0
crystal.build(solvator.box_dim/2)
# Out:
#  Crystal Parameters : Crystal Type = CUBI
#            A     =   50.66930 B    =   50.66930 C     =   50.66930
#            Alpha =   90.00000 Beta =   90.00000 Gamma =   90.00000
#  XBUILD> Building all transformations with a minimum atom-atom
#          contact distance of less than   25.33 Angstroms.
#
#  Range of Grid Search for Transformation     1 :
#  Lattice Vector A    -2 TO     2
#  Lattice Vector B    -2 TO     2
#  Lattice Vector C    -2 TO     2
#
#
#  The number of transformations generated =    26
#
#
#  Number  Symop   A   B   C   Distance
#
#       1      1  -1  -1  -1     5.6520
#       2      1  -1   0  -1     5.4010
#       3      1  -1   1  -1     7.1318
#       4      1   0  -1  -1     2.5438
#       5      1   0   0  -1     1.1614
#       6      1   0   1  -1     3.8318
#       7      1  -1  -1   0     3.4304
#       8      1  -1   0   0     1.9491
#       9      1  -1   1   0     3.9638
#      10      1   0  -1   0     1.3553
#      11      1   0   1   0     1.3553
#      12      1  -1  -1   1     4.2161
#      13      1  -1   0   1     4.0400
#      14      1  -1   1   1     7.1801
#      15      1   0  -1   1     3.8318
#      16      1   0   0   1     1.1614
#      17      1   0   1   1     2.5438
#      18      1   1   1   1     5.6520
#      19      1   1   0   1     5.4010
#      20      1   1  -1   1     7.1318
#      21      1   1   1   0     3.4304
#      22      1   1   0   0     1.9491
#      23      1   1  -1   0     3.9638
#      24      1   1   1  -1     4.2161
#      25      1   1   0  -1     4.0400
#      26      1   1  -1  -1     7.1801
#                      THERE ARE NO ROTATIONS FOR THIS TRANSFORMATION SET
#     26 Transformations have been processed.
# 1

# %%
# Turn on image centering - bysegment for protein, by residue for solvent and ions
# CHARMM scripting: image byseg xcen 0 ycen 0 zcen 0 select segid SEGID end
for segid in non_solvent_segids:
    image.setup_segment(0.0, 0.0, 0.0, segid)
# CHARMM scripting: image byres xcen 0 ycen 0 zcen 0 select resname tip3 end
image.setup_residue(0.0, 0.0, 0.0, 'TIP3')
# CHARMM scripting: image byres xcen 0 ycen 0 zcen 0 select resname ion_type end
for ion_type in all_ion_types:
    image.setup_residue(0.0, 0.0, 0.0, ion_type)
# Out:
#  select>    901 atoms have been selected out of   12160
#  IMAGE CENTERING ON FOR SOME ATOMS
#  select>  11253 atoms have been selected out of   12160
#  IMAGE CENTERING ON FOR SOME ATOMS
#  select>      6 atoms have been selected out of   12160
#  IMAGE CENTERING ON FOR SOME ATOMS

# %%
# Now specify nonbonded cutoffs for solvated box
cutnb = min(solvator.box_dim/2, 12)
cutim = cutnb
ctofnb = cutnb - 1.0
ctonnb = cutnb - 3.0

# Another nbonds example
# CHARMM scripting: nbonds cutnb @cutnb cutim @cutim ctofnb @ctofnb ctonnb @ctonnb -
#        inbfrq -1 imgfrq -1
non_bonded_script = pycharmm.NonBondedScript(
    cutnb=cutnb, cutim=cutim, ctonnb=ctonnb, ctofnb=ctofnb,
    eps=1.0,
    cdie=True,
    atom=True, vatom=True,
    fswitch=True, vfswitch=True,
    inbfrq=-1, imgfrq=-1
)

# %%
# We want to fix the protein and ligands and minimize the solvent to "fit"
# Select everything but solvent and ions
cons_fix_atoms = pycharmm.SelectAtoms()
for segid in non_solvent_segids:
    cons_fix_atoms |= pycharmm.SelectAtoms(seg_id=segid)

# Minimize the solvent positions with periodic boundary conditions using steepest descents
ener_dict = sd_minimize(200, non_bonded_script, cons_fix_selection=cons_fix_atoms)
# Out:
#
#  CHARMM>     nbonds cutnb 12 -
#  CHARMM>     cutim 12 -
#  CHARMM>     ctonnb 9.0 -
#  CHARMM>     ctofnb 11.0 -
#  CHARMM>     eps 1.0 -
#  CHARMM>     cdie -
#  CHARMM>     atom -
#  CHARMM>     vatom -
#  CHARMM>     fswitch -
#  CHARMM>     vfswitch -
#  CHARMM>     inbfrq -1 -
#  CHARMM>     imgfrq -1
#
#  SELECTED IMAGES ATOMS BEING CENTERED ABOUT  0.000000  0.000000  0.000000
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  N1N1N1R1 has      51      17      17        2.51
#     2  N1Z0N1R1 has     447     149     149        0.25
#     3  N1P1N1R1 has      51      17      17        3.76
#     4  Z0N1N1R1 has     483     161     161        1.43
#     5  Z0Z0N1R1 has    2819     941     941        0.08
#     6  Z0P1N1R1 has     449     151     151        0.47
#     7  N1N1Z0R1 has     522     174     174        0.27
#     8  N1Z0Z0R1 has    2804     930     918        0.14
#     9  N1P1Z0R1 has     444     148     148        1.23
#    10  Z0N1Z0R1 has    2890     964     964        0.07
#    12  N1N1P1R1 has      90      30      30        3.07
#    13  N1Z0P1R1 has     507     169     169        1.08
#    14  N1P1P1R1 has      36      12      12        2.30
#  Total of23753 atoms and 7896 groups and 7666 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 12.000 CTEXNB =999.000 CTONNB =  9.000 CTOFNB = 11.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  <MAKINB> with mode   5 found  13809 exclusions and   2364 interactions(1-4)
#  <MAKGRP> found    826 group exclusions.
#  <MAKGRP> found      0 image group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  2200426 ATOM PAIRS AND        0 GROUP PAIRS
#  == PRIMARY == SPACE FOR  3300659 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#   3154630 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    206227 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR  3012818 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    939706 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     91609 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#
#  CHARMM>
#
#
#  SELECTED IMAGES ATOMS BEING CENTERED ABOUT  0.000000  0.000000  0.000000
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  N1N1N1R1 has      51      17      17        2.51
#     2  N1Z0N1R1 has     447     149     149        0.25
#     3  N1P1N1R1 has      51      17      17        3.76
#     4  Z0N1N1R1 has     483     161     161        1.43
#     5  Z0Z0N1R1 has    2819     941     941        0.08
#     6  Z0P1N1R1 has     449     151     151        0.47
#     7  N1N1Z0R1 has     522     174     174        0.27
#     8  N1Z0Z0R1 has    2804     930     918        0.14
#     9  N1P1Z0R1 has     444     148     148        1.23
#    10  Z0N1Z0R1 has    2890     964     964        0.07
#    12  N1N1P1R1 has      90      30      30        3.07
#    13  N1Z0P1R1 has     507     169     169        1.08
#    14  N1P1P1R1 has      36      12      12        2.30
#  Total of23753 atoms and 7896 groups and 7666 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 12.000 CTEXNB =999.000 CTONNB =  9.000 CTOFNB = 11.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are  3154630 atom  pairs and    16173 atom  exclusions.
#  There are        0 group pairs and      826 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3300659 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#   3011652 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    198422 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR  3012818 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    939687 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     91601 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  PRNHBD: CUToff Hydrogen Bond  distance =    0.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
# /home/truman/crimm/crimm/Adaptors/pyCHARMMAdaptors.py:462: UserWarning: Atom fix constraint setup success: True
#   warnings.warn(f"Atom fix constraint setup success: {has_cons_fix}")
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#
#
#  STEEPD> An energy minimization has been requested.
#
#  NSTEP  =          200   NPRINT =           10
#  STEP   =    0.0200000   TOLFUN =    0.0010000
#  TOLGRD =    0.0010000   TOLSTP =    0.0000000
#
# MINI MIN: Cycle      ENERgy      Delta-E         GRMS    Step-size
# MINI INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# MINI EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# MINI IMAGES:        IMNBvdw       IMELec       IMHBnd       RXNField    EXTElec
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>        0 869619.11096-870521.39971  15521.96626      0.02000
# MINI INTERN>        1.00117      0.16965      0.00000      0.00000      0.00000
# MINI EXTERN>     4020.10803 -34252.94647      0.00000      0.00000      0.00000
# MINI IMAGES>   900739.80963   -889.03105      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       10 -34640.36846 904259.47943      6.61563      0.00896
# MINI INTERN>     1311.30233    842.88821      0.00000      0.00000      0.00000
# MINI EXTERN>     3630.53684 -39620.65673      0.00000      0.00000      0.00000
# MINI IMAGES>      419.55583  -1223.99493      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       20 -37477.53649   2837.16803      2.68990      0.00401
# MINI INTERN>     1089.38346    875.18100      0.00000      0.00000      0.00000
# MINI EXTERN>     3372.29922 -41216.88189      0.00000      0.00000      0.00000
# MINI IMAGES>      132.63550  -1730.15378      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       30 -38802.46945   1324.93296      4.17435      0.00431
# MINI INTERN>     1203.43923    909.63694      0.00000      0.00000      0.00000
# MINI EXTERN>     3290.37391 -42192.47899      0.00000      0.00000      0.00000
# MINI IMAGES>       61.20160  -2074.64214      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       40 -39673.35920    870.88974      4.60619      0.00464
# MINI INTERN>     1258.25422    924.03804      0.00000      0.00000      0.00000
# MINI EXTERN>     3281.08881 -42868.88820      0.00000      0.00000      0.00000
# MINI IMAGES>       35.41720  -2303.26926      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step        50
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3300659 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#   3022471 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    199730 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR  3012818 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    929081 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     91420 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>       50 -40322.45277    649.09358      5.09505      0.00498
# MINI INTERN>     1340.55943    921.94780      0.00000      0.00000      0.00000
# MINI EXTERN>     3303.14036 -43416.28453      0.00000      0.00000      0.00000
# MINI IMAGES>       12.52073  -2484.33656      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       60 -41028.39977    705.94699      1.06584      0.00223
# MINI INTERN>     1199.24133    916.22770      0.00000      0.00000      0.00000
# MINI EXTERN>     3336.52341 -43865.54864      0.00000      0.00000      0.00000
# MINI IMAGES>        9.04272  -2623.88629      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       70 -41502.64573    474.24596      1.64187      0.00240
# MINI INTERN>     1248.78810    927.71450      0.00000      0.00000      0.00000
# MINI EXTERN>     3389.45472 -44317.77571      0.00000      0.00000      0.00000
# MINI IMAGES>        3.68549  -2754.51283      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       80 -41842.02518    339.37945      2.48755      0.00258
# MINI INTERN>     1315.34488    940.08978      0.00000      0.00000      0.00000
# MINI EXTERN>     3440.78078 -44687.02377      0.00000      0.00000      0.00000
# MINI IMAGES>        1.57229  -2852.78914      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       90 -42142.80581    300.78063      2.66566      0.00277
# MINI INTERN>     1345.82835    947.13034      0.00000      0.00000      0.00000
# MINI EXTERN>     3494.45811 -45001.76104      0.00000      0.00000      0.00000
# MINI IMAGES>        1.03357  -2929.49515      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       100
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3300659 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#   3025897 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    199845 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR  3012818 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    925743 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     91377 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      100 -42398.05975    255.25394      2.91605      0.00298
# MINI INTERN>     1373.60389    950.88247      0.00000      0.00000      0.00000
# MINI EXTERN>     3550.74428 -45281.82269      0.00000      0.00000      0.00000
# MINI IMAGES>        0.41670  -2991.88440      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      110 -42715.21292    317.15316      0.96890      0.00133
# MINI INTERN>     1267.82306    934.81479      0.00000      0.00000      0.00000
# MINI EXTERN>     3604.03079 -45485.98487      0.00000      0.00000      0.00000
# MINI IMAGES>       -0.67104  -3035.22563      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      120 -42921.88639    206.67347      0.75215      0.00144
# MINI INTERN>     1283.95581    939.53770      0.00000      0.00000      0.00000
# MINI EXTERN>     3655.97309 -45718.46161      0.00000      0.00000      0.00000
# MINI IMAGES>        0.22430  -3083.11567      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      130 -43120.37115    198.48476      0.86240      0.00154
# MINI INTERN>     1292.11130    941.44692      0.00000      0.00000      0.00000
# MINI EXTERN>     3711.11747 -45938.42759      0.00000      0.00000      0.00000
# MINI IMAGES>        1.09864  -3127.71788      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      140 -43288.75917    168.38802      1.56379      0.00166
# MINI INTERN>     1297.91176    940.34166      0.00000      0.00000      0.00000
# MINI EXTERN>     3764.97643 -46127.79880      0.00000      0.00000      0.00000
# MINI IMAGES>        1.69916  -3165.88938      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       150
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3300659 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#   3027738 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    199810 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR  3012818 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    923875 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     91212 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      150 -43446.63264    157.87347      1.86911      0.00178
# MINI INTERN>     1313.16812    943.67965      0.00000      0.00000      0.00000
# MINI EXTERN>     3816.85916 -46319.09819      0.00000      0.00000      0.00000
# MINI IMAGES>        2.69334  -3203.93471      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      160 -43595.25700    148.62436      1.93977      0.00192
# MINI INTERN>     1325.23268    945.92035      0.00000      0.00000      0.00000
# MINI EXTERN>     3866.00090 -46497.55359      0.00000      0.00000      0.00000
# MINI IMAGES>        3.78422  -3238.64156      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      170 -43730.60676    135.34976      1.97795      0.00206
# MINI INTERN>     1328.77140    947.31780      0.00000      0.00000      0.00000
# MINI EXTERN>     3911.33812 -46654.48319      0.00000      0.00000      0.00000
# MINI IMAGES>        4.99238  -3268.54326      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      180 -43855.88768    125.28092      2.18886      0.00221
# MINI INTERN>     1344.18317    951.40968      0.00000      0.00000      0.00000
# MINI EXTERN>     3957.35649 -46814.98685      0.00000      0.00000      0.00000
# MINI IMAGES>        5.87295  -3299.72312      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      190 -44014.69453    158.80686      0.54694      0.00099
# MINI INTERN>     1362.09276    963.01996      0.00000      0.00000      0.00000
# MINI EXTERN>     3999.44385 -47011.14988      0.00000      0.00000      0.00000
# MINI IMAGES>        8.11989  -3336.22111      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       200
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3300659 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#   3028777 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    199753 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR  3012818 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    922685 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     91144 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      200 -44134.90759    120.21306      0.56470      0.00107
# MINI INTERN>     1372.21666    966.33214      0.00000      0.00000      0.00000
# MINI EXTERN>     4043.15956 -47160.92455      0.00000      0.00000      0.00000
# MINI IMAGES>        9.50750  -3365.19890      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  STEEPD> Minimization exiting with number of steps limit (       200) exceeded.
#
# STPD MIN: Cycle      ENERgy      Delta-E         GRMS    Step-size
# STPD INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# STPD EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# STPD IMAGES:        IMNBvdw       IMELec       IMHBnd       RXNField    EXTElec
#  ----------       ---------    ---------    ---------    ---------    ---------
# STPD>      200 -44134.90759    120.21306      0.56470      0.00128
# STPD INTERN>     1372.21666    966.33214      0.00000      0.00000      0.00000
# STPD EXTERN>     4043.15956 -47160.92455      0.00000      0.00000      0.00000
# STPD IMAGES>        9.50750  -3365.19890      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  SELECTED IMAGES ATOMS BEING CENTERED ABOUT  0.000000  0.000000  0.000000
#  RESIDUE  221 OPERATED ON BY TRANSFORMATION Z0P1Z0R1
#  RESIDUE  369 OPERATED ON BY TRANSFORMATION Z0P1Z0R1
#  RESIDUE 1507 OPERATED ON BY TRANSFORMATION Z0P1Z0R1
#  RESIDUE 1651 OPERATED ON BY TRANSFORMATION Z0P1Z0R1
#  RESIDUE 2084 OPERATED ON BY TRANSFORMATION N1Z0Z0R1
#  RESIDUE 2538 OPERATED ON BY TRANSFORMATION N1Z0Z0R1
#  RESIDUE 3398 OPERATED ON BY TRANSFORMATION N1Z0Z0R1
#  RESIDUE 3803 OPERATED ON BY TRANSFORMATION N1Z0Z0R1
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  N1N1N1R1 has      54      18      18        2.00
#     2  N1Z0N1R1 has     447     149     149        0.74
#     3  N1P1N1R1 has      48      16      16        3.29
#     4  Z0N1N1R1 has     474     158     158        1.33
#     5  Z0Z0N1R1 has    2780     928     928        0.00
#     6  Z0P1N1R1 has     437     147     147        0.19
#     7  N1N1Z0R1 has     504     168     168        0.11
#     8  N1Z0Z0R1 has    2745     910     900        0.00
#     9  N1P1Z0R1 has     438     146     146        1.11
#    10  Z0N1Z0R1 has    2863     955     955        0.00
#    12  N1N1P1R1 has      87      29      29        2.77
#    13  N1Z0P1R1 has     498     166     166        0.64
#    14  N1P1P1R1 has      36      12      12        1.87
#  Total of23571 atoms and 7835 groups and 7607 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 12.000 CTEXNB =999.000 CTONNB =  9.000 CTOFNB = 11.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are  3028777 atom  pairs and    16173 atom  exclusions.
#  There are        0 group pairs and      826 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3300659 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#   3171764 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    207591 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR  3012818 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    922706 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     91145 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  PRNHBD: CUToff Hydrogen Bond  distance =    0.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
#
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
# ENER ENR:  Eval#     ENERgy      Delta-E         GRMS
# ENER INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# ENER CROSS:           CMAPs        PMF1D        PMF2D        PRIMO
# ENER EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# ENER IMAGES:        IMNBvdw       IMELec       IMHBnd       RXNField    EXTElec
#  ----------       ---------    ---------    ---------    ---------    ---------
# ENER>        0 -44880.15941    745.25181      0.88694
# ENER INTERN>     1430.53430   1101.30387      8.75453    477.17038      6.57932
# ENER CROSS>       -14.88658      0.00000      0.00000      0.00000
# ENER EXTERN>     3863.74475 -48428.04908      0.00000      0.00000      0.00000
# ENER IMAGES>        8.47122  -3333.78212      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------

# %%
fetch_coords_from_charmm(model)
model
# Out:
# NGLWidget()
# <OrganizedModel model=4PTI Polypeptide(L)=1 Solvent=2 Ion=1 >
# 	│
# 	├───<Polypeptide(L) id=A Residues=58>
# 	├──────Description: TRYPSIN INHIBITOR
# 	│
# 	├───<Solvent id=B Residues=60>
# 	├──────Residue ID(s): HOH
# 	├──────Description: water
# 	│
# 	├───<Solvent id=WA Residues=3691>
# 	├──────Description: water
# 	│
# 	├───<Ion id=IA Residues=6>
# 	├──────Description: balancing ions (CLA)

# %%
pcm_write.coor_card(f'{PDBID}.crd')
pcm_write.psf_card(f'{PDBID}.psf')
# Out:
#
#  CHARMM>     write name 4E0J.crd -
#  CHARMM>     coor card
#  VOPEN> Attempting to open::4e0j.crd::
#  RDTITL>
#  RDTITL> No title read.
#  VCLOSE: Closing unit   91 with status "KEEP"
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     write name 4E0J.psf -
#  CHARMM>     psf card
#  VOPEN> Attempting to open::4e0j.psf::
#  RDTITL>
#  RDTITL> No title read.
#  VCLOSE: Closing unit   91 with status "KEEP"
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
